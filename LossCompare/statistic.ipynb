# %%
import csv
from scipy.stats import shapiro
from scipy import stats
import pandas as pd
import numpy as np
from statsmodels.stats.anova import AnovaRM
import matplotlib.pyplot as plt
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %% [markdown]
# Shapiro Wilk Test - Normal Distribution - Parametric Testing

# %% [markdown]
#  Extarcting data from "evaluation_loss.csv" file for each loss function

# %% [markdown]
# Cosine

# %%
#  Extarcting data from "evaluation_loss.csv" file for cosine
cosine = np.array([
17.7061,
20.0664,
20.4256,
18.58,
20.3451,
20.4634,
18.8391,
21.6425,
20.3374,
17.5323,
20.3779,
20.5711,
17.6875,
21.1727,
20.5124,
18.5495,
20.3569,
20.3484,
21.0485,
22.3074,
21.9025,
19.0856,
22.6122,
20.1927,
17.693,
20.7592,
20.6431,
17.8369,
20.3674,
21.3079,
15.4266,
17.1752,
19.8003,
15.6693,
19.0305,
19.4818,
15.7398,
19.719,
19.0982,
15.7467,
17.8519,
19.5881,
15.7676,
18.5017,
19.7395,
15.7221,
17.5879,
19.7928,
17.8321,
17.8594,
20.5681,
15.8187,
19.9709,
19.391,
15.539,
17.5388,
23.3462,
15.5731,
17.791,
18.6966,
17.3366,
20.2694,
20.3154,
18.5829,
21.8205,
20.3958,
18.3517,
22.8613,
20.3113,
18.033,
21.8554,
20.4705,
18.321,
23.2523,
20.2865,
18.1357,
20.532,
20.3747,
23.5518,
21.4778,
20.5058,
18.2012,
23.3586,
20.4309,
17.1152,
20.332,
22.5743,
17.1148,
20.3344,
23.4729


])

# %%
from scipy import stats
# Shapiro Wilk Test
res = stats.shapiro(cosine)
p = res.statistic
print(f'Shapiro WIlk Test cosine {p}')
# Out:
# Shapiro WIlk Test cosine 0.9645796183166074

# %%
plt.figure(figsize=(6, 6))
stats.probplot(cosine, dist="norm", plot=plt)
plt.title("Q-Q Plot")
plt.grid(True, linestyle='--', alpha=0.05)
plt.tight_layout()
plt.show()

# %% [markdown]
# MSE KickTime

# %%
#  Extarcting data from "evaluation_loss.csv" file for mse kikctime
mse_kicktime = np.array([
0.713472559,
0.518657207,
0.537905312,
0.580135174,
0.519395323,
0.550727784,
0.584567103,
0.515012667,
0.539201964,
0.92247689,
0.51948735,
0.531042392,
0.95034249,
0.51742044,
0.53440267,
0.935954154,
0.519320024,
0.539224147,
0.610134287,
0.539780135,
0.532796735,
0.624669614,
0.507279868,
0.548609639,
0.809071444,
0.519675406,
0.53512652,
0.757445164,
0.519560223,
0.649594806,
0.702161491,
0.430644448,
0.531427185,
0.570306799,
0.427235679,
0.513142919,
0.605878438,
0.421794567,
0.507436202,
0.584512443,
0.430980824,
0.522506459,
0.628343224,
0.42949832,
0.521691213,
0.64426456,
0.431154119,
0.527292228,
0.555865105,
0.441689757,
0.519936588,
0.638178059,
0.416365763,
0.512016779,
0.552006496,
0.431551124,
0.733641392,
0.612129543,
0.43181522,
0.503969413,
0.924854593,
0.530367174,
0.545649306,
0.58067215,
0.5263929,
0.54150581,
0.839819359,
0.513733899,
0.548428628,
0.890033395,
0.528959314,
0.587069033,
0.887952877,
0.52300661,
0.548105105,
0.83264857,
0.530863029,
0.544726881,
0.609613126,
0.543447126,
0.54776824,
0.805509452,
0.502500466,
0.546726347,
0.70197824,
0.531012928,
0.698975307,
0.721152321,
0.530793466,
0.734908885



])

# %%
plt.figure(figsize=(6, 6))
stats.probplot(mse_kicktime, dist="norm", plot=plt)
plt.title("Q-Q Plot")
plt.grid(True, linestyle='--', alpha=0.05)
plt.tight_layout()
plt.show()

# %%
# Shaptiro Wilk for MSE Kicktime - squarred error loss
res = stats.shapiro(mse_kicktime)
shapiro_mse_kicktime = res.statistic
shapiro_mse_kicktime
# Out:
# 0.8355824902018563

# %% [markdown]
# MSE Trajectory

# %%
#  Extarcting data from "evaluation_loss.csv" file for mse trajectory
mse_trajectory = np.array([
271.4485615,
5.47352068,
1.110565243,
5.263532269,
3.128242291,
1.108199767,
4.212893551,
8.368645286,
1.111679234,
21.27619192,
2.963023254,
1.106485851,
17.04574108,
2.549535023,
1.113304116,
5.682385009,
3.24428457,
1.109327171,
5.748912338,
5.240349161,
1.230415382,
2.481771044,
14.46088104,
1.126585428,
181.4363629,
2.770929474,
1.176839837,
285.8312319,
3.534801668,
1.373399649,
19.48893925,
4.168351568,
1.095369459,
9.122524651,
6.178665366,
1.058160495,
7.907282832,
9.084370076,
1.070862893,
7.069257342, 
3.681861954,
1.099378247,
8.871513522,
6.168589038, 
1.095523895,
7.152129698,
3.007254102,
1.087616533,
5.431645184,
3.251617288,
1.553959167,
7.364690458,
11.63456363,
1.067199854,
44.22257547,
2.767151806,
1.576581209,
86.96305758,
2.55181267,
1.350954911,
7.905986796,
1.448177203,
1.122408287,
3.873277835,
9.002413047,
1.127648652,
16.94815344,
18.83754524,
1.131189918,
12.05934691,
9.471445412,
1.198373536,
11.97059822,
16.84708164,
1.146917574,
18.78385228,
2.47434707,
1.121753467,
10.05037533,
1.59336473,
1.592889602,
17.72007799,
22.90274329,
1.128859105,
69.56268894,
1.360543615,
1.402508234,
95.14698403,
1.267276303,
1.537940991])

# %%
plt.figure(figsize=(6, 6))
stats.probplot(mse_trajectory, dist="norm", plot=plt)
plt.title("Q-Q Plot")
plt.grid(True, linestyle='--', alpha=0.05)
plt.tight_layout()
plt.show()

# %%
# Shaprio Wilk Test results for MSE Trajectory - Squared error loss over the whole trajectory
res = stats.shapiro(mse_trajectory)
shapiro_trajectory = res.statistic
shapiro_trajectory
# Out:
# 0.34433386528101373

# %% [markdown]
# Levene - Homogenity of Variance - Parametric Testing

# %%
levene_cosine_orientation = [cosine[:30], cosine[30:60], cosine[60:]]
print(levene_cosine_orientation)
# Out:
# [array([17.7061, 20.0664, 20.4256, 18.58  , 20.3451, 20.4634, 18.8391,
#        21.6425, 20.3374, 17.5323, 20.3779, 20.5711, 17.6875, 21.1727,
#        20.5124, 18.5495, 20.3569, 20.3484, 21.0485, 22.3074, 21.9025,
#        19.0856, 22.6122, 20.1927, 17.693 , 20.7592, 20.6431, 17.8369,
#        20.3674, 21.3079]), array([15.4266, 17.1752, 19.8003, 15.6693, 19.0305, 19.4818, 15.7398,
#        19.719 , 19.0982, 15.7467, 17.8519, 19.5881, 15.7676, 18.5017,
#        19.7395, 15.7221, 17.5879, 19.7928, 17.8321, 17.8594, 20.5681,
#        15.8187, 19.9709, 19.391 , 15.539 , 17.5388, 23.3462, 15.5731,
#        17.791 , 18.6966]), array([17.3366, 20.2694, 20.3154, 18.5829, 21.8205, 20.3958, 18.3517,
#        22.8613, 20.3113, 18.033 , 21.8554, 20.4705, 18.321 , 23.2523,
#        20.2865, 18.1357, 20.532 , 20.3747, 23.5518, 21.4778, 20.5058,
#        18.2012, 23.3586, 20.4309, 17.1152, 20.332 , 22.5743, 17.1148,
#        20.3344, 23.4729])]

# %%
from scipy.stats import levene

group1 = cosine[:30]
group2 = cosine[30:60]
group3 = cosine[60:]

stat, p_value = levene(group1, group2, group3)
print(f"Levene’s test statistic = {stat:.5f}, p-value = {p_value:.5f}")
# Out:
# Levene’s test statistic = 2.00883, p-value = 0.14032

# %%
group1 = mse_trajectory[:30]
group2 = mse_trajectory[30:60]
group3 = mse_trajectory[60:]

stat, p_value = levene(group1, group2, group3)
print(f"Levene’s test statistic = {stat:.5f}, p-value = {p_value:.5f}")
# Out:
# Levene’s test statistic = 1.63584, p-value = 0.20072

# %%
group1 = mse_kicktime[:30]
group2 = mse_kicktime[30:60]
group3 = mse_kicktime[60:]

stat, p_value = levene(group1, group2, group3)
print(f"Levene’s test statistic = {stat:.5f}, p-value = {p_value:.5f}")
# Out:
# Levene’s test statistic = 0.52515, p-value = 0.59333

# %% [markdown]
# ANOVA

# %%
# Load the data from the evaluation.csv file
filename = "evaluation_loss.csv"

with open(filename, mode="r", encoding="utf-8") as file:
    reader = csv.DictReader(file)
    raw_data = []
    for row in reader:
        raw_data.append(row)

# extract Loss function and its respective data
loss_function_to_use = "Cosine"

reshaped_data = []
for row in raw_data:
    reshaped_row = {}
    reshaped_row["fitness"] = (float(row[loss_function_to_use]) * (1))
    reshaped_row["bias_mode"] = row["Bias_Mode"]
    reshaped_row["sort_criteria"] = row["Sorted Velocity Criteria"]
    reshaped_row["model"] = row["Model"]
    reshaped_data.append(reshaped_row)

# Create a dictionary for statsmodels 
fitness = []
bias_mode = []
sort_criteria = []

for row in reshaped_data:
    fitness.append(row["fitness"])
    bias_mode.append(row["bias_mode"])
    sort_criteria.append(row["sort_criteria"])


data_dict = {
    "Fitness": fitness,
    "BiasMode": bias_mode,
    "SortCriteria": sort_criteria
}

# ANOVA
model = ols('Fitness ~ C(BiasMode) + C(SortCriteria) + C(BiasMode):C(SortCriteria)', data=data_dict).fit()
anova_table = sm.stats.anova_lm(model, typ=2)

print(anova_table)
# Out:
#                                  sum_sq    df          F    PR(>F)
# C(BiasMode)                   10.886459   9.0   0.297570  0.972715
# C(SortCriteria)               85.783907   2.0  10.551676  0.000118
# C(BiasMode):C(SortCriteria)    4.547227  18.0   0.062147  1.000000
# Residual                     243.896528  60.0        NaN       NaN

# %%
# Tukey Test Pairwise
tukey = pairwise_tukeyhsd(endog=fitness, groups=sort_criteria, alpha=0.05)
print(tukey)
# Out:
#     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===========================================================
#  group1     group2   meandiff p-adj   lower   upper  reject
# -----------------------------------------------------------
#  bearing    distance  -2.1972    0.0 -3.2602 -1.1343   True
#  bearing orientation  -0.2811 0.8038  -1.344  0.7819  False
# distance orientation   1.9161 0.0001  0.8532  2.9791   True
# -----------------------------------------------------------

# %% [markdown]
# Calculating the mean - which loss has the lowest mean - best fitness

# %%
sum_distance = 0
count_distance = 0

for fitness, sort_criteria in zip(data_dict['Fitness'], data_dict['SortCriteria']):
    if sort_criteria == 'distance':
        sum_distance += fitness
        count_distance += 1

mean_distance = sum_distance / count_distance

print(f'Distance mean: {mean_distance}')
# Out:
# Distance mean: 18.005009999999995

# %%
sum_distance = 0
count_distance = 0

for fitness, sort_criteria in zip(data_dict['Fitness'], data_dict['SortCriteria']):
    if sort_criteria == 'bearing':
        sum_distance += fitness
        count_distance += 1

mean_distance = sum_distance / count_distance

print(f'Bearing mean: {mean_distance}')
# Out:
# Bearing mean: 20.202233333333332

# %%
sum_distance = 0
count_distance = 0

for fitness, sort_criteria in zip(data_dict['Fitness'], data_dict['SortCriteria']):
    if sort_criteria == 'orientation':
        sum_distance += fitness
        count_distance += 1

mean_distance = sum_distance / count_distance

print(f'Orientation mean: {mean_distance}')
# Out:
# Orientation mean: 19.92115

# %%
# load the data from the evaluation.csv file
filename = "evaluation_loss.csv"

with open(filename, mode="r", encoding="utf-8") as file:
    reader = csv.DictReader(file)
    raw_data = []
    for row in reader:
        raw_data.append(row)

# Loss  - respective data
loss_function_to_use = "MSE_Trajectory"

reshaped_data = []
for row in raw_data:
    reshaped_row = {}
    reshaped_row["fitness"] = float(row[loss_function_to_use])
    reshaped_row["bias_mode"] = row["Bias_Mode"]
    reshaped_row["sort_criteria"] = row["Sorted Velocity Criteria"]
    reshaped_row["model"] = row["Model"]
    reshaped_data.append(reshaped_row)

fitness = []
bias_mode = []
sort_criteria = []

for row in reshaped_data:
    fitness.append(row["fitness"])
    bias_mode.append(row["bias_mode"])
    sort_criteria.append(row["sort_criteria"])

# Create a dictionary for statsmodels
data_dict = {
    "Fitness": fitness,
    "BiasMode": bias_mode,
    "SortCriteria": sort_criteria
}

# ANOVA
model = ols('Fitness ~ C(BiasMode) + C(SortCriteria) + C(BiasMode):C(SortCriteria)', data=data_dict).fit()
anova_table = sm.stats.anova_lm(model, typ=2)


print(anova_table)
# Out:
#                                     sum_sq    df         F    PR(>F)
# C(BiasMode)                   24818.096659   9.0  1.183186  0.322268
# C(SortCriteria)                6736.337241   2.0  1.445177  0.243790
# C(BiasMode):C(SortCriteria)   20836.343054  18.0  0.496679  0.949618
# Residual                     139837.662544  60.0       NaN       NaN

# %%
# Tukey Test Pairwise
key = pairwise_tukeyhsd(endog=fitness, groups=sort_criteria, alpha=0.05)
print(key)
# Out:
#     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ============================================================
#  group1     group2   meandiff p-adj   lower    upper  reject
# ------------------------------------------------------------
#  bearing    distance  -3.1992 0.9611 -31.6275 25.2291  False
#  bearing orientation  16.5426 0.3518 -11.8857 44.9709  False
# distance orientation  19.7418 0.2281  -8.6865 48.1701  False
# ------------------------------------------------------------

# %%
# load the data from the evaluation.csv file
filename = "evaluation_loss.csv"

with open(filename, mode="r", encoding="utf-8") as file:
    reader = csv.DictReader(file)
    raw_data = []
    for row in reader:
        raw_data.append(row)

# Loss  - respective data
loss_function_to_use = "MSE Kicktime"

reshaped_data = []
for row in raw_data:
    reshaped_row = {}
    reshaped_row["fitness"] = float(row[loss_function_to_use])
    reshaped_row["bias_mode"] = row["Bias_Mode"]
    reshaped_row["sort_criteria"] = row["Sorted Velocity Criteria"]
    reshaped_row["model"] = row["Model"]
    reshaped_data.append(reshaped_row)

# Create a dictionary for statsmodels
fitness = []
bias_mode = []
sort_criteria = []

for row in reshaped_data:
    fitness.append(row["fitness"])
    bias_mode.append(row["bias_mode"])
    sort_criteria.append(row["sort_criteria"])

data_dict = {
    "Fitness": fitness,
    "BiasMode": bias_mode,
    "SortCriteria": sort_criteria
}

# ANOVA
model = ols('Fitness ~ C(BiasMode) + C(SortCriteria) + C(BiasMode):C(SortCriteria)', data=data_dict).fit()
anova_table = sm.stats.anova_lm(model, typ=2)

print(anova_table)
# Out:
#                                sum_sq    df         F    PR(>F)
# C(BiasMode)                  0.084034   9.0  0.486148  0.878273
# C(SortCriteria)              0.178244   2.0  4.640271  0.013372
# C(BiasMode):C(SortCriteria)  0.046389  18.0  0.134184  0.999989
# Residual                     1.152375  60.0       NaN       NaN

# %%
# Tukey Test Pairwise
tukey = pairwise_tukeyhsd(endog=fitness, groups=sort_criteria, alpha=0.05)
print(tukey)
# Out:
#     Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===========================================================
#  group1     group2   meandiff p-adj   lower   upper  reject
# -----------------------------------------------------------
#  bearing    distance  -0.1039 0.0038 -0.1787 -0.0291   True
#  bearing orientation  -0.0234 0.7372 -0.0981  0.0514  False
# distance orientation   0.0805 0.0317  0.0058  0.1553   True
# -----------------------------------------------------------

# %%
sum_distance = 0
count_distance = 0

distance_fitness = []

for fitness, sort_criteria in zip(data_dict['Fitness'], data_dict['SortCriteria']):
    if sort_criteria == 'distance':
        sum_distance += fitness
        count_distance += 1
        distance_fitness.append(fitness)


mean_distance = sum_distance / count_distance 

print(f'Distance mean: {mean_distance}')
# Out:
# Distance mean: 0.5254311910834064

# %%
sum_distance = 0
count_distance = 0

for fitness, sort_criteria in zip(data_dict['Fitness'], data_dict['SortCriteria']):
    if sort_criteria == 'bearing':
        sum_distance += fitness
        count_distance += 1

mean_distance = sum_distance / count_distance

print(f'Bearing mean: {mean_distance}')
# Out:
# Bearing mean: 0.6293255059402539

# %%
sum_distance = 0
count_distance = 0

for fitness, sort_criteria in zip(data_dict['Fitness'], data_dict['SortCriteria']):
    if sort_criteria == 'orientation':
        sum_distance += fitness
        count_distance += 1

mean_distance = sum_distance / count_distance

print(f'Orientation mean: {mean_distance}')
# Out:
# Orientation mean: 0.6059562452864242

# %% [markdown]
# POstHoc Test on Distance -> Bias Mode to figure out which one is better

# %%
# Load the data from the evaluation.csv file
filename = "evaluation_loss.csv"
with open(filename, mode="r", encoding="utf-8") as file:
    reader = csv.DictReader(file)
    raw_data = []
    for row in reader:
        raw_data.append(row)

loss_function = "Cosine" 
sort_method = "distance"

# Filter data: Sorted Velocity Criteria = distance
fitness = []
bias_mode = []

for row in raw_data:
    if row["Sorted Velocity Criteria"].strip().lower() == sort_method:
        fitness_val = float(row[loss_function])
        fitness.append(fitness_val)
        bias_mode.append(row["Bias_Mode"])

# ANOVA
data_dict = {
    "Fitness": fitness,
    "BiasMode": bias_mode
}

model = ols("Fitness ~ C(BiasMode)", data=data_dict).fit()
anova_table = sm.stats.anova_lm(model, typ=2)

print(f"\n=== ANOVA for BiasMode (Loss = {loss_function}, Sort = {sort_method}) ===")
print(anova_table)

# Tukey HSD post-hoc test
print(f"\n=== Tukey HSD for BiasMode (Loss = {loss_function}, Sort = {sort_method}) ===")
tukey = pairwise_tukeyhsd(endog=fitness, groups=bias_mode, alpha=0.05)
print(tukey)
# Out:
# === ANOVA for BiasMode (Loss = Cosine, Sort = distance) ===
#                  sum_sq    df         F   PR(>F)
# C(BiasMode)    5.495116   9.0  0.115677  0.99888
# Residual     105.563975  20.0       NaN      NaN
#
# === Tukey HSD for BiasMode (Loss = Cosine, Sort = distance) ===
#                                                   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================================================================================================================
#                          group1                                                   group2                          meandiff p-adj   lower  upper  reject
# -------------------------------------------------------------------------------------------------------------------------------------------------------
#                                       bias_negative_None                                       bias_positive_None   1.4544 0.9982 -5.1881  8.097  False
#                                       bias_negative_None                                         bias_random_None   0.9951 0.9999 -5.6475 7.6377  False
#                                       bias_negative_None                                           bias_wall_None     1.04 0.9999 -5.6026 7.6825  False
#                                       bias_negative_None           bias_wall_zone_bias_wall_zone_alignment_domain   0.8321    1.0 -5.8105 7.4747  False
#                                       bias_negative_None             bias_wall_zone_bias_wall_zone_alignment_zone    0.707    1.0 -5.9356 7.3495  False
#                                       bias_negative_None bias_wall_zone_bias_wall_zone_repulsion_alignment_domain   0.6494    1.0 -5.9932 7.2919  False
#                                       bias_negative_None   bias_wall_zone_bias_wall_zone_repulsion_alignment_zone   0.3753    1.0 -6.2672 7.0179  False
#                                       bias_negative_None             bias_wall_zone_bias_wall_zone_repulsion_zone   0.1138    1.0 -6.5288 6.7564  False
#                                       bias_negative_None                                           bias_zero_None   0.3474    1.0 -6.2952 6.9899  False
#                                       bias_positive_None                                         bias_random_None  -0.4593    1.0 -7.1019 6.1832  False
#                                       bias_positive_None                                           bias_wall_None  -0.4145    1.0  -7.057 6.2281  False
#                                       bias_positive_None           bias_wall_zone_bias_wall_zone_alignment_domain  -0.6223    1.0 -7.2649 6.0202  False
#                                       bias_positive_None             bias_wall_zone_bias_wall_zone_alignment_zone  -0.7475    1.0   -7.39 5.8951  False
#                                       bias_positive_None bias_wall_zone_bias_wall_zone_repulsion_alignment_domain  -0.8051    1.0 -7.4476 5.8375  False
#                                       bias_positive_None   bias_wall_zone_bias_wall_zone_repulsion_alignment_zone  -1.0791 0.9998 -7.7217 5.5635  False
#                                       bias_positive_None             bias_wall_zone_bias_wall_zone_repulsion_zone  -1.3406 0.9991 -7.9832 5.3019  False
#                                       bias_positive_None                                           bias_zero_None  -1.1071 0.9998 -7.7496 5.5355  False
#                                         bias_random_None                                           bias_wall_None   0.0449    1.0 -6.5977 6.6874  False
#                                         bias_random_None           bias_wall_zone_bias_wall_zone_alignment_domain   -0.163    1.0 -6.8056 6.4796  False
#                                         bias_random_None             bias_wall_zone_bias_wall_zone_alignment_zone  -0.2881    1.0 -6.9307 6.3544  False
#                                         bias_random_None bias_wall_zone_bias_wall_zone_repulsion_alignment_domain  -0.3457    1.0 -6.9883 6.2968  False
#                                         bias_random_None   bias_wall_zone_bias_wall_zone_repulsion_alignment_zone  -0.6198    1.0 -7.2623 6.0228  False
#                                         bias_random_None             bias_wall_zone_bias_wall_zone_repulsion_zone  -0.8813    1.0 -7.5239 5.7613  False
#                                         bias_random_None                                           bias_zero_None  -0.6477    1.0 -7.2903 5.9948  False
#                                           bias_wall_None           bias_wall_zone_bias_wall_zone_alignment_domain  -0.2079    1.0 -6.8504 6.4347  False
#                                           bias_wall_None             bias_wall_zone_bias_wall_zone_alignment_zone   -0.333    1.0 -6.9756 6.3096  False
#                                           bias_wall_None bias_wall_zone_bias_wall_zone_repulsion_alignment_domain  -0.3906    1.0 -7.0332  6.252  False
#                                           bias_wall_None   bias_wall_zone_bias_wall_zone_repulsion_alignment_zone  -0.6646    1.0 -7.3072 5.9779  False
#                                           bias_wall_None             bias_wall_zone_bias_wall_zone_repulsion_zone  -0.9262    1.0 -7.5687 5.7164  False
#                                           bias_wall_None                                           bias_zero_None  -0.6926    1.0 -7.3352   5.95  False
#           bias_wall_zone_bias_wall_zone_alignment_domain             bias_wall_zone_bias_wall_zone_alignment_zone  -0.1251    1.0 -6.7677 6.5174  False
#           bias_wall_zone_bias_wall_zone_alignment_domain bias_wall_zone_bias_wall_zone_repulsion_alignment_domain  -0.1827    1.0 -6.8253 6.4598  False
#           bias_wall_zone_bias_wall_zone_alignment_domain   bias_wall_zone_bias_wall_zone_repulsion_alignment_zone  -0.4568    1.0 -7.0993 6.1858  False
#           bias_wall_zone_bias_wall_zone_alignment_domain             bias_wall_zone_bias_wall_zone_repulsion_zone  -0.7183    1.0 -7.3609 5.9243  False
#           bias_wall_zone_bias_wall_zone_alignment_domain                                           bias_zero_None  -0.4847    1.0 -7.1273 6.1578  False
#             bias_wall_zone_bias_wall_zone_alignment_zone bias_wall_zone_bias_wall_zone_repulsion_alignment_domain  -0.0576    1.0 -6.7002  6.585  False
#             bias_wall_zone_bias_wall_zone_alignment_zone   bias_wall_zone_bias_wall_zone_repulsion_alignment_zone  -0.3316    1.0 -6.9742 6.3109  False
#             bias_wall_zone_bias_wall_zone_alignment_zone             bias_wall_zone_bias_wall_zone_repulsion_zone  -0.5932    1.0 -7.2357 6.0494  False
#             bias_wall_zone_bias_wall_zone_alignment_zone                                           bias_zero_None  -0.3596    1.0 -7.0022  6.283  False
# bias_wall_zone_bias_wall_zone_repulsion_alignment_domain   bias_wall_zone_bias_wall_zone_repulsion_alignment_zone   -0.274    1.0 -6.9166 6.3685  False
# bias_wall_zone_bias_wall_zone_repulsion_alignment_domain             bias_wall_zone_bias_wall_zone_repulsion_zone  -0.5356    1.0 -7.1781  6.107  False
# bias_wall_zone_bias_wall_zone_repulsion_alignment_domain                                           bias_zero_None   -0.302    1.0 -6.9446 6.3406  False
#   bias_wall_zone_bias_wall_zone_repulsion_alignment_zone             bias_wall_zone_bias_wall_zone_repulsion_zone  -0.2615    1.0 -6.9041  6.381  False
#   bias_wall_zone_bias_wall_zone_repulsion_alignment_zone                                           bias_zero_None   -0.028    1.0 -6.6705 6.6146  False
#             bias_wall_zone_bias_wall_zone_repulsion_zone                                           bias_zero_None   0.2336    1.0  -6.409 6.8761  False
# -------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Load the data from the evaluation.csv file
filename = "evaluation_loss.csv"
with open(filename, mode="r", encoding="utf-8") as file:
    reader = csv.DictReader(file)
    raw_data = []
    for row in reader:
        raw_data.append(row)

loss_function = "MSE Kicktime" 
sort_method = "distance"

# Filter data: Sorted Velocity Criteria = distance
fitness = []
bias_mode = []

for row in raw_data:
    if row["Sorted Velocity Criteria"].strip().lower() == sort_method:
        fitness_val = float(row[loss_function])
        fitness.append(fitness_val)
        bias_mode.append(row["Bias_Mode"])

# ANOVA
data_dict = {
    "Fitness": fitness,
    "BiasMode": bias_mode
}

model = ols("Fitness ~ C(BiasMode)", data=data_dict).fit()
anova_table = sm.stats.anova_lm(model, typ=2)

print(f"\n=== ANOVA for BiasMode (Loss = {loss_function}, Sort = {sort_method}) ===")
print(anova_table)

# Tukey HSD post-hoc test
print(f"\n=== Tukey HSD for BiasMode (Loss = {loss_function}, Sort = {sort_method}) ===")
tukey = pairwise_tukeyhsd(endog=fitness, groups=bias_mode, alpha=0.05)
print(tukey)
# Out:
# === ANOVA for BiasMode (Loss = MSE Kicktime, Sort = distance) ===
#                sum_sq    df         F    PR(>F)
# C(BiasMode)  0.014111   9.0  0.146673  0.997205
# Residual     0.213797  20.0       NaN       NaN
#
# === Tukey HSD for BiasMode (Loss = MSE Kicktime, Sort = distance) ===
#                                                   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =======================================================================================================================================================
#                          group1                                                   group2                          meandiff p-adj   lower  upper  reject
# -------------------------------------------------------------------------------------------------------------------------------------------------------
#                                       bias_negative_None                                       bias_positive_None   0.0564 0.9994 -0.2425 0.3554  False
#                                       bias_negative_None                                         bias_random_None  -0.0156    1.0 -0.3146 0.2833  False
#                                       bias_negative_None                                           bias_wall_None   0.0062    1.0 -0.2927 0.3052  False
#                                       bias_negative_None           bias_wall_zone_bias_wall_zone_alignment_domain  -0.0043    1.0 -0.3032 0.2947  False
#                                       bias_negative_None             bias_wall_zone_bias_wall_zone_alignment_zone  -0.0124    1.0 -0.3113 0.2865  False
#                                       bias_negative_None bias_wall_zone_bias_wall_zone_repulsion_alignment_domain   0.0105    1.0 -0.2884 0.3095  False
#                                       bias_negative_None   bias_wall_zone_bias_wall_zone_repulsion_alignment_zone  -0.0033    1.0 -0.3022 0.2956  False
#                                       bias_negative_None             bias_wall_zone_bias_wall_zone_repulsion_zone   0.0388    1.0 -0.2602 0.3377  False
#                                       bias_negative_None                                           bias_zero_None   0.0183    1.0 -0.2807 0.3172  False
#                                       bias_positive_None                                         bias_random_None  -0.0721 0.9964  -0.371 0.2269  False
#                                       bias_positive_None                                           bias_wall_None  -0.0502 0.9998 -0.3491 0.2487  False
#                                       bias_positive_None           bias_wall_zone_bias_wall_zone_alignment_domain  -0.0607  0.999 -0.3596 0.2382  False
#                                       bias_positive_None             bias_wall_zone_bias_wall_zone_alignment_zone  -0.0688 0.9974 -0.3678 0.2301  False
#                                       bias_positive_None bias_wall_zone_bias_wall_zone_repulsion_alignment_domain  -0.0459 0.9999 -0.3448  0.253  False
#                                       bias_positive_None   bias_wall_zone_bias_wall_zone_repulsion_alignment_zone  -0.0597 0.9991 -0.3587 0.2392  False
#                                       bias_positive_None             bias_wall_zone_bias_wall_zone_repulsion_zone  -0.0177    1.0 -0.3166 0.2813  False
#                                       bias_positive_None                                           bias_zero_None  -0.0382    1.0 -0.3371 0.2608  False
#                                         bias_random_None                                           bias_wall_None   0.0219    1.0 -0.2771 0.3208  False
#                                         bias_random_None           bias_wall_zone_bias_wall_zone_alignment_domain   0.0114    1.0 -0.2876 0.3103  False
#                                         bias_random_None             bias_wall_zone_bias_wall_zone_alignment_zone   0.0032    1.0 -0.2957 0.3022  False
#                                         bias_random_None bias_wall_zone_bias_wall_zone_repulsion_alignment_domain   0.0262    1.0 -0.2728 0.3251  False
#                                         bias_random_None   bias_wall_zone_bias_wall_zone_repulsion_alignment_zone   0.0123    1.0 -0.2866 0.3113  False
#                                         bias_random_None             bias_wall_zone_bias_wall_zone_repulsion_zone   0.0544 0.9996 -0.2445 0.3534  False
#                                         bias_random_None                                           bias_zero_None   0.0339    1.0  -0.265 0.3328  False
#                                           bias_wall_None           bias_wall_zone_bias_wall_zone_alignment_domain  -0.0105    1.0 -0.3094 0.2885  False
#                                           bias_wall_None             bias_wall_zone_bias_wall_zone_alignment_zone  -0.0186    1.0 -0.3176 0.2803  False
#                                           bias_wall_None bias_wall_zone_bias_wall_zone_repulsion_alignment_domain   0.0043    1.0 -0.2946 0.3033  False
#                                           bias_wall_None   bias_wall_zone_bias_wall_zone_repulsion_alignment_zone  -0.0095    1.0 -0.3085 0.2894  False
#                                           bias_wall_None             bias_wall_zone_bias_wall_zone_repulsion_zone   0.0326    1.0 -0.2664 0.3315  False
#                                           bias_wall_None                                           bias_zero_None   0.0121    1.0 -0.2869  0.311  False
#           bias_wall_zone_bias_wall_zone_alignment_domain             bias_wall_zone_bias_wall_zone_alignment_zone  -0.0081    1.0 -0.3071 0.2908  False
#           bias_wall_zone_bias_wall_zone_alignment_domain bias_wall_zone_bias_wall_zone_repulsion_alignment_domain   0.0148    1.0 -0.2841 0.3137  False
#           bias_wall_zone_bias_wall_zone_alignment_domain   bias_wall_zone_bias_wall_zone_repulsion_alignment_zone    0.001    1.0  -0.298 0.2999  False
#           bias_wall_zone_bias_wall_zone_alignment_domain             bias_wall_zone_bias_wall_zone_repulsion_zone    0.043 0.9999 -0.2559  0.342  False
#           bias_wall_zone_bias_wall_zone_alignment_domain                                           bias_zero_None   0.0225    1.0 -0.2764 0.3215  False
#             bias_wall_zone_bias_wall_zone_alignment_zone bias_wall_zone_bias_wall_zone_repulsion_alignment_domain   0.0229    1.0  -0.276 0.3219  False
#             bias_wall_zone_bias_wall_zone_alignment_zone   bias_wall_zone_bias_wall_zone_repulsion_alignment_zone   0.0091    1.0 -0.2898  0.308  False
#             bias_wall_zone_bias_wall_zone_alignment_zone             bias_wall_zone_bias_wall_zone_repulsion_zone   0.0512 0.9997 -0.2478 0.3501  False
#             bias_wall_zone_bias_wall_zone_alignment_zone                                           bias_zero_None   0.0307    1.0 -0.2683 0.3296  False
# bias_wall_zone_bias_wall_zone_repulsion_alignment_domain   bias_wall_zone_bias_wall_zone_repulsion_alignment_zone  -0.0138    1.0 -0.3128 0.2851  False
# bias_wall_zone_bias_wall_zone_repulsion_alignment_domain             bias_wall_zone_bias_wall_zone_repulsion_zone   0.0282    1.0 -0.2707 0.3272  False
# bias_wall_zone_bias_wall_zone_repulsion_alignment_domain                                           bias_zero_None   0.0077    1.0 -0.2912 0.3067  False
#   bias_wall_zone_bias_wall_zone_repulsion_alignment_zone             bias_wall_zone_bias_wall_zone_repulsion_zone   0.0421 0.9999 -0.2569  0.341  False
#   bias_wall_zone_bias_wall_zone_repulsion_alignment_zone                                           bias_zero_None   0.0216    1.0 -0.2774 0.3205  False
#             bias_wall_zone_bias_wall_zone_repulsion_zone                                           bias_zero_None  -0.0205    1.0 -0.3194 0.2784  False
# -------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Load the data from the evaluation.csv file
filename = "evaluation_loss.csv"
with open(filename, mode="r", encoding="utf-8") as file:
    reader = csv.DictReader(file)
    raw_data = []
    for row in reader:
        raw_data.append(row)

loss_function = "Cosine" 
sort_method = "MSE_Trajectory"

# Filter data: Sorted Velocity Criteria = distance
fitness = []
bias_mode = []

for row in raw_data:
    if row["Sorted Velocity Criteria"].strip().lower() == sort_method:
        fitness_val = float(row[loss_function])
        fitness.append(fitness_val)
        bias_mode.append(row["Bias_Mode"])

# ANOVA
data_dict = {
    "Fitness": fitness,
    "BiasMode": bias_mode
}

model = ols("Fitness ~ C(BiasMode)", data=data_dict).fit()
anova_table = sm.stats.anova_lm(model, typ=2)

print(f"\n=== ANOVA for BiasMode (Loss = {loss_function}, Sort = {sort_method}) ===")
print(anova_table)

# Tukey HSD post-hoc test
print(f"\n=== Tukey HSD for BiasMode (Loss = {loss_function}, Sort = {sort_method}) ===")
tukey = pairwise_tukeyhsd(endog=fitness, groups=bias_mode, alpha=0.05)
print(tukey)
# Out:
# === ANOVA for BiasMode (Loss = MSE_Trajectory, Sort = distance) ===
#                   sum_sq    df         F    PR(>F)
# C(BiasMode)  1895.299482   9.0  0.657888  0.736029
# Residual     6401.968820  20.0       NaN       NaN
#
# === Tukey HSD for BiasMode (Loss = MSE_Trajectory, Sort = distance) ===
#                                                    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# =========================================================================================================================================================
#                          group1                                                   group2                          meandiff p-adj   lower    upper  reject
# ---------------------------------------------------------------------------------------------------------------------------------------------------------
#                                       bias_negative_None                                       bias_positive_None -14.0998 0.9913  -65.829 37.6293  False
#                                       bias_negative_None                                         bias_random_None  -27.068 0.6973 -78.7972 24.6611  False
#                                       bias_negative_None                                           bias_wall_None -23.5998 0.8261 -75.3289 28.1294  False
#                                       bias_negative_None           bias_wall_zone_bias_wall_zone_alignment_domain -24.2678 0.8035 -75.9969 27.4614  False
#                                       bias_negative_None             bias_wall_zone_bias_wall_zone_alignment_zone -24.8355 0.7833 -76.5646 26.8937  False
#                                       bias_negative_None bias_wall_zone_bias_wall_zone_repulsion_alignment_domain -24.9101 0.7806 -76.6392 26.8191  False
#                                       bias_negative_None   bias_wall_zone_bias_wall_zone_repulsion_alignment_zone -26.3384 0.7264 -78.0676 25.3907  False
#                                       bias_negative_None             bias_wall_zone_bias_wall_zone_repulsion_zone -22.0377 0.8736 -73.7669 29.6914  False
#                                       bias_negative_None                                           bias_zero_None -26.5396 0.7185 -78.2688 25.1895  False
#                                       bias_positive_None                                         bias_random_None -12.9682 0.9952 -64.6973  38.761  False
#                                       bias_positive_None                                           bias_wall_None     -9.5 0.9995 -61.2291 42.2292  False
#                                       bias_positive_None           bias_wall_zone_bias_wall_zone_alignment_domain -10.1679 0.9992 -61.8971 41.5612  False
#                                       bias_positive_None             bias_wall_zone_bias_wall_zone_alignment_zone -10.7357 0.9988 -62.4648 40.9935  False
#                                       bias_positive_None bias_wall_zone_bias_wall_zone_repulsion_alignment_domain -10.8102 0.9988 -62.5394 40.9189  False
#                                       bias_positive_None   bias_wall_zone_bias_wall_zone_repulsion_alignment_zone -12.2386 0.9968 -63.9677 39.4905  False
#                                       bias_positive_None             bias_wall_zone_bias_wall_zone_repulsion_zone  -7.9379 0.9999  -59.667 43.7913  False
#                                       bias_positive_None                                           bias_zero_None -12.4398 0.9964 -64.1689 39.2894  False
#                                         bias_random_None                                           bias_wall_None   3.4682    1.0 -48.2609 55.1974  False
#                                         bias_random_None           bias_wall_zone_bias_wall_zone_alignment_domain   2.8003    1.0 -48.9289 54.5294  False
#                                         bias_random_None             bias_wall_zone_bias_wall_zone_alignment_zone   2.2325    1.0 -49.4966 53.9617  False
#                                         bias_random_None bias_wall_zone_bias_wall_zone_repulsion_alignment_domain    2.158    1.0 -49.5712 53.8871  False
#                                         bias_random_None   bias_wall_zone_bias_wall_zone_repulsion_alignment_zone   0.7296    1.0 -50.9996 52.4587  False
#                                         bias_random_None             bias_wall_zone_bias_wall_zone_repulsion_zone   5.0303    1.0 -46.6988 56.7594  False
#                                         bias_random_None                                           bias_zero_None   0.5284    1.0 -51.2007 52.2576  False
#                                           bias_wall_None           bias_wall_zone_bias_wall_zone_alignment_domain   -0.668    1.0 -52.3971 51.0612  False
#                                           bias_wall_None             bias_wall_zone_bias_wall_zone_alignment_zone  -1.2357    1.0 -52.9648 50.4934  False
#                                           bias_wall_None bias_wall_zone_bias_wall_zone_repulsion_alignment_domain  -1.3103    1.0 -53.0394 50.4189  False
#                                           bias_wall_None   bias_wall_zone_bias_wall_zone_repulsion_alignment_zone  -2.7387    1.0 -54.4678 48.9905  False
#                                           bias_wall_None             bias_wall_zone_bias_wall_zone_repulsion_zone   1.5621    1.0 -50.1671 53.2912  False
#                                           bias_wall_None                                           bias_zero_None  -2.9398    1.0  -54.669 48.7893  False
#           bias_wall_zone_bias_wall_zone_alignment_domain             bias_wall_zone_bias_wall_zone_alignment_zone  -0.5677    1.0 -52.2969 51.1614  False
#           bias_wall_zone_bias_wall_zone_alignment_domain bias_wall_zone_bias_wall_zone_repulsion_alignment_domain  -0.6423    1.0 -52.3714 51.0868  False
#           bias_wall_zone_bias_wall_zone_alignment_domain   bias_wall_zone_bias_wall_zone_repulsion_alignment_zone  -2.0707    1.0 -53.7998 49.6585  False
#           bias_wall_zone_bias_wall_zone_alignment_domain             bias_wall_zone_bias_wall_zone_repulsion_zone     2.23    1.0 -49.4991 53.9592  False
#           bias_wall_zone_bias_wall_zone_alignment_domain                                           bias_zero_None  -2.2718    1.0  -54.001 49.4573  False
#             bias_wall_zone_bias_wall_zone_alignment_zone bias_wall_zone_bias_wall_zone_repulsion_alignment_domain  -0.0746    1.0 -51.8037 51.6546  False
#             bias_wall_zone_bias_wall_zone_alignment_zone   bias_wall_zone_bias_wall_zone_repulsion_alignment_zone   -1.503    1.0 -53.2321 50.2262  False
#             bias_wall_zone_bias_wall_zone_alignment_zone             bias_wall_zone_bias_wall_zone_repulsion_zone   2.7978    1.0 -48.9314 54.5269  False
#             bias_wall_zone_bias_wall_zone_alignment_zone                                           bias_zero_None  -1.7041    1.0 -53.4333  50.025  False
# bias_wall_zone_bias_wall_zone_repulsion_alignment_domain   bias_wall_zone_bias_wall_zone_repulsion_alignment_zone  -1.4284    1.0 -53.1575 50.3008  False
# bias_wall_zone_bias_wall_zone_repulsion_alignment_domain             bias_wall_zone_bias_wall_zone_repulsion_zone   2.8723    1.0 -48.8568 54.6015  False
# bias_wall_zone_bias_wall_zone_repulsion_alignment_domain                                           bias_zero_None  -1.6295    1.0 -53.3587 50.0996  False
#   bias_wall_zone_bias_wall_zone_repulsion_alignment_zone             bias_wall_zone_bias_wall_zone_repulsion_zone   4.3007    1.0 -47.4284 56.0299  False
#   bias_wall_zone_bias_wall_zone_repulsion_alignment_zone                                           bias_zero_None  -0.2012    1.0 -51.9303  51.528  False
#             bias_wall_zone_bias_wall_zone_repulsion_zone                                           bias_zero_None  -4.5019    1.0  -56.231 47.2273  False
# ---------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# RQ1 - T Test - Fitness value

# %%
#  Extarcting data from "evaluation_loss.csv" file
cosine = np.array([
17.7061,
20.0664,
20.4256,
18.58,
20.3451,
20.4634,
18.8391,
21.6425,
20.3374,
17.5323,
20.3779,
20.5711,
17.6875,
21.1727,
20.5124,
18.5495,
20.3569,
20.3484,
21.0485,
22.3074,
21.9025,
19.0856,
22.6122,
20.1927,
17.693,
20.7592,
20.6431,
17.8369,
20.3674,
21.3079,
15.4266,
17.1752,
19.8003,
15.6693,
19.0305,
19.4818,
15.7398,
19.719,
19.0982,
15.7467,
17.8519,
19.5881,
15.7676,
18.5017,
19.7395,
15.7221,
17.5879,
19.7928,
17.8321,
17.8594,
20.5681,
15.8187,
19.9709,
19.391,
15.539,
17.5388,
23.3462,
15.5731,
17.791,
18.6966,
17.3366,
20.2694,
20.3154,
18.5829,
21.8205,
20.3958,
18.3517,
22.8613,
20.3113,
18.033,
21.8554,
20.4705,
18.321,
23.2523,
20.2865,
18.1357,
20.532,
20.3747,
23.5518,
21.4778,
20.5058,
18.2012,
23.3586,
20.4309,
17.1152,
20.332,
22.5743,
17.1148,
20.3344,
23.4729


])

results = stats.ttest_1samp(
    cosine, 
    popmean=0,
    alternative = 'greater'
)

print(f"t({results.df}) = {results.statistic:.2f}, p = {results.pvalue:.4f}")
# Out:
# t(89) = 90.19, p = 0.0000

# %%
#  Extarcting data from "evaluation_loss.csv" file
mse_kicktime = np.array([
0.713472559,
0.518657207,
0.537905312,
0.580135174,
0.519395323,
0.550727784,
0.584567103,
0.515012667,
0.539201964,
0.92247689,
0.51948735,
0.531042392,
0.95034249,
0.51742044,
0.53440267,
0.935954154,
0.519320024,
0.539224147,
0.610134287,
0.539780135,
0.532796735,
0.624669614,
0.507279868,
0.548609639,
0.809071444,
0.519675406,
0.53512652,
0.757445164,
0.519560223,
0.649594806,
0.702161491,
0.430644448,
0.531427185,
0.570306799,
0.427235679,
0.513142919,
0.605878438,
0.421794567,
0.507436202,
0.584512443,
0.430980824,
0.522506459,
0.628343224,
0.42949832,
0.521691213,
0.64426456,
0.431154119,
0.527292228,
0.555865105,
0.441689757,
0.519936588,
0.638178059,
0.416365763,
0.512016779,
0.552006496,
0.431551124,
0.733641392,
0.612129543,
0.43181522,
0.503969413,
0.924854593,
0.530367174,
0.545649306,
0.58067215,
0.5263929,
0.54150581,
0.839819359,
0.513733899,
0.548428628,
0.890033395,
0.528959314,
0.587069033,
0.887952877,
0.52300661,
0.548105105,
0.83264857,
0.530863029,
0.544726881,
0.609613126,
0.543447126,
0.54776824,
0.805509452,
0.502500466,
0.546726347,
0.70197824,
0.531012928,
0.698975307,
0.721152321,
0.530793466,
0.734908885



])




results = stats.ttest_1samp(
    mse_kicktime, 
    popmean=0,
    alternative = 'greater'
)

print(f"t({results.df}) = {results.statistic:.2f}, p = {results.pvalue:.4f}")
# Out:
# t(89) = 43.54, p = 0.0000

# %%
#  Extarcting data from "evaluation_loss.csv"
mse_trajectory = np.array([
271.4485615,
5.47352068,
1.110565243,
5.263532269,
3.128242291,
1.108199767,
4.212893551,
8.368645286,
1.111679234,
21.27619192,
2.963023254,
1.106485851,
17.04574108,
2.549535023,
1.113304116,
5.682385009,
3.24428457,
1.109327171,
5.748912338,
5.240349161,
1.230415382,
2.481771044,
14.46088104,
1.126585428,
181.4363629,
2.770929474,
1.176839837,
285.8312319,
3.534801668,
1.373399649,
19.48893925,
4.168351568,
1.095369459,
9.122524651,
6.178665366,
1.058160495,
7.907282832,
9.084370076,
1.070862893,
7.069257342, 
3.681861954,
1.099378247,
8.871513522,
6.168589038, 
1.095523895,
7.152129698,
3.007254102,
1.087616533,
5.431645184,
3.251617288,
1.553959167,
7.364690458,
11.63456363,
1.067199854,
44.22257547,
2.767151806,
1.576581209,
86.96305758,
2.55181267,
1.350954911,
7.905986796,
1.448177203,
1.122408287,
3.873277835,
9.002413047,
1.127648652,
16.94815344,
18.83754524,
1.131189918,
12.05934691,
9.471445412,
1.198373536,
11.97059822,
16.84708164,
1.146917574,
18.78385228,
2.47434707,
1.121753467,
10.05037533,
1.59336473,
1.592889602,
17.72007799,
22.90274329,
1.128859105,
69.56268894,
1.360543615,
1.402508234,
95.14698403,
1.267276303,
1.537940991])

results = stats.ttest_1samp(
    mse_trajectory, 
    popmean=0,
    alternative = 'greater'
)

print(f"t({results.df}) = {results.statistic:.2f}, p = {results.pvalue:.4f}")
# Out:
# t(89) = 3.39, p = 0.0005
